# %% [markdown]
# <a href="https://colab.research.google.com/github/Tulasipotu08/hackathon/blob/main/IPL_SCORE_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
ipl = pd.read_csv('ipl_dataset.csv')
#print(ipl)

# %%
#Dropping certain features
df = ipl.drop(['full_scorecard','margin', 'man_of_the_match', 'stadium', 'place'], axis =1)

# %%
df.head(200)
# Out:
#                            team1                  team2  team1_score  \
# 0            Chennai Super Kings  Kolkata Knight Riders        131.0
# 1                 Mumbai Indians         Delhi Capitals        177.0
# 2    Royal Challengers Bangalore           Punjab Kings        205.0
# 3           Lucknow Super Giants         Gujarat Titans        158.0
# 4               Rajasthan Royals    Sunrisers Hyderabad        210.0
# ..                           ...                    ...          ...
# 195          Sunrisers Hyderabad  Kolkata Knight Riders        181.0
# 196               Delhi Capitals         Mumbai Indians        213.0
# 197              Kings XI Punjab       Rajasthan Royals        184.0
# 198               Delhi Capitals    Chennai Super Kings        147.0
# 199        Kolkata Knight Riders        Kings XI Punjab        218.0
#
#      team2_score            toss_winner toss_choice    winner
# 0          133.0  Kolkata Knight Riders       Field       KKR
# ...

# %%
df.groupby('winner').describe()
# Out:
#             team1_score                                                       \
#                   count        mean        std    min     25%    50%     75%
# winner
# Capitals           33.0  168.151515  28.177031  115.0  152.00  163.0  188.00
# Chargers           29.0  157.517241  22.631553  101.0  143.00  160.0  174.00
# Daredevils         64.0  162.218750  29.144669   92.0  142.00  164.0  186.25
# Guj                13.0  165.307692  21.433559  124.0  158.00  171.0  180.00
# KKR               111.0  158.036036  28.719309   81.0  138.00  160.0  175.50
# Kings              83.0  165.253012  31.530412   67.0  148.50  167.0  186.50
# Kochi               5.0  141.400000  31.317727   97.0  132.00  140.0  156.00
# Match               0.0         NaN        NaN    NaN     NaN    NaN     NaN
# Mumbai            128.0  164.117188  29.936579   67.0  149.75  168.0  183.00
# No                  1.0  187.000000        NaN  187.0  187.00  187.0  187.00
# ...

# %%
# prompt: drop Deccan Chargers , Delhi Daredevils	 , Gujarat Lions , Kochi Tuskers Kerala , Rising Pune Supergiant	, Rising Pune Supergiants from the entire dataset

df = df.drop(df.loc[df['winner'].isin(['Match','No','Tied','Chargers', 'Daredevils', 'Gujarat Lions', 'Kochi', 'Supergiant', 'Supergiants','Pune Warriors'])].index)

# %%
df.groupby('winner').describe()
# Out:
#           team1_score                                                       \
#                 count        mean        std    min     25%    50%     75%
# winner
# Capitals         33.0  168.151515  28.177031  115.0  152.00  163.0  188.00
# Guj              13.0  165.307692  21.433559  124.0  158.00  171.0  180.00
# KKR             111.0  158.036036  28.719309   81.0  138.00  160.0  175.50
# Kings            83.0  165.253012  31.530412   67.0  148.50  167.0  186.50
# Mumbai          128.0  164.117188  29.936579   67.0  149.75  168.0  183.00
# Punjab           13.0  171.846154  32.043840  125.0  143.00  179.0  198.00
# RCB             102.0  165.784314  32.633163   82.0  149.00  165.0  181.75
# Royals           93.0  165.107527  30.359964   70.0  145.00  164.0  189.00
# Sunrisers        74.0  157.472973  31.627638   68.0  135.00  154.0  178.50
# Super           128.0  167.765625  28.560334   70.0  148.00  166.0  185.25
# ...

# %%
toss_winners3 = {}
for i, row in df.iterrows():
  if row['toss_winner'] not in toss_winners3:
    toss_winners3[row['toss_winner']] = len(toss_winners3)

# %%
#df.to_dict('dict')
teams = {"Kings": 0, "Mumbai": 1, "Royals" : 2, "Super" : 3, "Royals" : 4, "Sunrises"  : 5, "Capitals" : 6,  "Punjab"  : 7,  "KKR" : 8, "Punjab" : 9, "Titans" : 10 ,"Guj" :11}

# %%
df['winner1'] = df['winner'].apply(lambda x:teams.get(x,-1))
df['new_toss'] = df['toss_winner'].apply(lambda x:toss_winners3.get(x,-1))
dic = {'Field': 0 ,'Bat':1}
df['newc'] = df['toss_choice'].apply(lambda x:dic.get(x,-1))

# %%
df.head()
# Out:
#                          team1                  team2  team1_score  \
# 0          Chennai Super Kings  Kolkata Knight Riders        131.0
# 1               Mumbai Indians         Delhi Capitals        177.0
# 2  Royal Challengers Bangalore           Punjab Kings        205.0
# 3         Lucknow Super Giants         Gujarat Titans        158.0
# 4             Rajasthan Royals    Sunrisers Hyderabad        210.0
#
#    team2_score            toss_winner toss_choice    winner  team11  team12  \
# 0        133.0  Kolkata Knight Riders       Field       KKR       0       5
# 1        179.0         Delhi Capitals       Field  Capitals       1       8
# 2        208.0           Punjab Kings       Field    Punjab       2       6
# 3        161.0         Gujarat Titans       Field    Titans       3       7
# 4        149.0    Sunrisers Hyderabad       Field    Royals       4       9
#
#    winner1  new_toss  newc
# 0        8         0     0
# 1        6         1     0
# ...

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-109-bf934754a5b1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
x= df[['new_toss','newc']]
y= df['winner1']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=2)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)

# %%
x_test
# Out:
#      new_toss  newc
# 665         7     0
# 888        18     0
# 753        -1     1
# 780        18     0
# 419        10     1
# ..        ...   ...
# 455         5     0
# 72          9     0
# 2           2     0
# 333        13     0
# 363        11     0
#
# [288 rows x 2 columns]

# %%
c = [17,1]
c = np.array(c)
c = c.reshape(-1, 2)

# %%
r = model.predict(c)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
r
# Out:
# array([0.38148419])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, pred)
print(f"Mean squared error: {mse}")
# Out:
# Mean squared error: 12.176564574855776
